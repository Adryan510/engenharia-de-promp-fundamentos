# %% [markdown]
# <a href="https://colab.research.google.com/github/Adryan510/engenharia-de-promp-fundamentos/blob/main/Programa%C3%A7%C3%A3oAssistidaPorAI_aula07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula 07 _  miniprojeto
#
# Nome:Adryan da Silva
# Disciplina: Engenharia de Prompt e Aplicação em IA

# %%
print("hello word!")
# Out:
# hello word!

# %%
numeros = [10, 20, 30, 40, 50] # Exemplo de como definir a lista
soma = 0
i = 0
while i < len(numeros):
  soma += numeros[i]
  i += 1
print(f"A soma dos números é: {soma}")
# Out:
# A soma dos números é: 150
